# %%
# creamos una clase llamada TiendaOnline
class TiendaOnline:
    def __init__ (self):
        self.inventario = [] #inventario (lista de diccionarios): el producto representado por un diccionario
        self.clientes = {} #clientes (diccionario)
        self.ventas_totales = 0 #ventas_totales (float)
        

    # Método para agregar producto
    def agregar_producto(self, nombre, precio, cantidad):
        #Crear el diccionario del producto
        producto = {"nombre":nombre, "precio":precio, "cantidad":cantidad} 
        #Verifica si el producto ya existe en el inventario
        for item in self.inventario:
            if item ["nombre"] == nombre:
                #Actualizar la cantidad del producto existente
                item ["cantidad"] += cantidad
                print(f"El producto'{nombre}' ha sido actualizado. Nueva cantidad: 40")
                return
                print(f"El producto '{nombre}' ya existe")

        #Si el producto no existe, agregarlo al inventario
        self.inventario.append(producto)
        print(f"producto '{nombre}' agregado con éxito.")

    # Método para buscar un producto en el inventario (nombre)
    def buscar_producto(self, nombre):
        for item in self.inventario: 
            if item ["nombre"] == nombre: 
                return item
        return
    
    # Método actualizar stock
    def actualizar_stock (self, nombre, cantidad):
        for item in self.inventario:
            if item ["nombre"] == nombre:
                item["cantidad"]+= cantidad 
                print(f"el stock del producto '{nombre}' ha sido actualizado. Nueva cantidad: {item['cantidad']}")
                return
        print(f"No se encontro el producto '{nombre}'")

    # Método eliminar producto
    def eliminar_producto (self, nombre):
        for item in self.inventario:
            if item ["nombre"] == nombre: 
                del self.inventario[1]
                print(f"Producto'{nombre}'eliminado con éxito.")
                return
        print(f"no se encontro el producto '{nombre}' en el inventario")

    # Método calcular valor total inventario 
    def calcular_valor_inventario (self):
        valor_total = 0
        for producto in self.inventario:
           valor_total += producto["precio"] * producto["cantidad"]
        return valor_total
    
    # Método mostrar inventario
    def mostrar_inventario(self):
        if not self.inventario:
            print("el inventario está vacio")
        else: 
            print("Inventario:")
            for producto in self.inventario:
                print(f"producto","precio","cantidad")

    # Método realizar compra
    def seguir_comprando():
        respuesta = input("¿Desea seguir comprando? (yes/no):")
        if respuesta() == "yes":
            return True
        elif respuesta() == "no":
            return False
        else:
            return
    while True:
        if seguir_comprando ():
            print("Continuar comprando")
        else: 
            print ("Gracias por comprar en nuestra tienda")
            break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # creamos una clase llamada TiendaOnline
# ----> 2 class TiendaOnline:
#       3     def __init__ (self):
#       4         self.inventario = [] #inventario (lista de diccionarios): el producto representado por un diccionario
#
# Cell In[9], line 77, in TiendaOnline()
#      75         return
#      76 while True:
# ---> 77     if seguir_comprando ():
#      78         print("Continuar comprando")
#      79     else:
#
# Cell In[9], line 70, in TiendaOnline.seguir_comprando()
#      68 def seguir_comprando():
#      69     respuesta = input("¿Desea seguir comprando? (yes/no):")
# ---> 70     if respuesta() == "yes":
#      71         return True
#      72     elif respuesta() == "no":
#
# TypeError: 'str' object is not callable

# %%
#Crear una instancia de la clase TiendaOnline
tienda = TiendaOnline()

# Agregar productos al inventario
tienda.agregar_producto ("camisa", 20, 30)
tienda.agregar_producto ("pantalon", 30, 30)
tienda.agregar_producto ("camisa", 20, 10)
tienda.agregar_producto ("zapatos", 50, 40)
tienda.agregar_producto ("camiseta", 20, 50)

# Mostrar el inventario
print("Inventario:")
for producto in tienda.inventario:
    print(producto)


# Buscar un producto en el inventario 
producto_buscado = tienda.buscar_producto("camisa")
if producto_buscado:
    print(f"Producto encontrado: {producto_buscado}")
else:
    print("Producto no encontrado.")

#Actualizar el stock de un producto 
tienda.actualizar_stock ("camisa", 10)
tienda.actualizar_stock ("falda", 15)

# Eliminamos un producto del inventario
tienda.eliminar_producto("zapatos")

print ("inventario")
for producto in tienda.inventario:
    print(producto)

# calcular el valor total del inventario
valor_inventario = tienda.calcular_valor_inventario()
print(f"El valor total del inventario es ${valor_inventario}")
# Out:
# producto 'camisa' agregado con éxito.
# producto 'pantalon' agregado con éxito.
# El producto'camisa' ha sido actualizado. Nueva cantidad: 40
# producto 'zapatos' agregado con éxito.
# producto 'camiseta' agregado con éxito.
# Inventario:
# {'nombre': 'camisa', 'precio': 20, 'cantidad': 40}
# {'nombre': 'pantalon', 'precio': 30, 'cantidad': 30}
# {'nombre': 'zapatos', 'precio': 50, 'cantidad': 40}
# {'nombre': 'camiseta', 'precio': 20, 'cantidad': 50}
# Producto encontrado: {'nombre': 'camisa', 'precio': 20, 'cantidad': 40}
# el stock del producto 'camisa' ha sido actualizado. Nueva cantidad: 50
# No se encontro el producto 'falda'
# Producto'zapatos'eliminado con éxito.
# inventario
# {'nombre': 'camisa', 'precio': 20, 'cantidad': 50}
# {'nombre': 'zapatos', 'precio': 50, 'cantidad': 40}
# {'nombre': 'camiseta', 'precio': 20, 'cantidad': 50}
# El valor total del inventario es $4000
